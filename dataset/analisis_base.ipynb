# %%
import pandas as pd

# %%
corpus=[]
target=[]
edad=[]
sexo=[]
severidad=[]
archivo=open("dataset_elpino.csv",encoding="utf-8")
header=archivo.readline().strip().split(";")
features=[]
for col in header:
    col=col.split("-")[0].strip()
    if col.startswith("Diag") or col.startswith("Proc"):
        col=col.split(" ")
        col=col[0]+col[1]
    features.append(col)
for linea in archivo:
    row=[]
    linea=linea.strip().split(";")
    for i in range(len(linea)):
        col=linea[i].split("-")[0].strip()
        if i==67:
            grd=col
            #target.append(grd[-1])
            target.append(grd)
        elif i==66:
            sexo.append(1 if col=="Mujer" else 0)
        elif i==65:
            edad.append(int(col))
        else:
            row.append(col)
    corpus.append(row)

# %%
corpus[0]
# Out:
# ['A41.8',
#  'B37.6',
#  'I39.8',
#  'N10',
#  'B96.1',
#  'L89.9',
#  'L08.9',
#  'B96.2',
#  'A41.5',
#  'J86.9',
#  'U07.1',
#  'Y95',
#  'N18.5',
#  'E87.1',
#  'D64.9',
#  'G82.2',
#  'N31.9',
#  'I10',
#  'K70.4',
#  'F19.2',
#  'F10.2',
#  'E46',
#  'G40.9',
#  'L21.9',
#  'Z93.5',
#  'Z93.3',
#  'Z99.2',
#  'Z91.6',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '86.28',
#  '34.91',
#  '88.38',
#  '87.41',
#  '88.75',
#  '88.01',
#  '88.43',
#  '88.41',
#  '87.44',
#  '99.29',
#  '99.19',
#  '99.18',
#  '99.21',
#  '99.26',
#  '99.23',
#  '93.94',
#  '89.52',
#  '90.59',
#  '89.65',
#  '39.95',
#  '39.95',
#  '99.04',
#  '90.39',
#  '99.84',
#  '88.72',
#  '90.42',
#  '90.52',
#  '91.39',
#  '91.33',
#  '87.03']

# %%
features
# Out:
# ['Diag01',
#  'Diag02',
#  'Diag03',
#  'Diag04',
#  'Diag05',
#  'Diag06',
#  'Diag07',
#  'Diag08',
#  'Diag09',
#  'Diag10',
#  'Diag11',
#  'Diag12',
#  'Diag13',
#  'Diag14',
#  'Diag15',
#  'Diag16',
#  'Diag17',
#  'Diag18',
#  'Diag19',
#  'Diag20',
#  'Diag21',
#  'Diag22',
#  'Diag23',
#  'Diag24',
#  'Diag25',
#  'Diag26',
#  'Diag27',
#  'Diag28',
#  'Diag29',
#  'Diag30',
#  'Diag31',
#  'Diag32',
#  'Diag33',
#  'Diag34',
#  'Diag35',
#  'Proced01',
#  'Proced02',
#  'Proced03',
#  'Proced04',
#  'Proced05',
#  'Proced06',
#  'Proced07',
#  'Proced08',
#  'Proced09',
#  'Proced10',
#  'Proced11',
#  'Proced12',
#  'Proced13',
#  'Proced14',
#  'Proced15',
#  'Proced16',
#  'Proced17',
#  'Proced18',
#  'Proced19',
#  'Proced20',
#  'Proced21',
#  'Proced22',
#  'Proced23',
#  'Proced24',
#  'Proced25',
#  'Proced26',
#  'Proced27',
#  'Proced28',
#  'Proced29',
#  'Proced30',
#  'Edad en años',
#  'Sexo (Desc)',
#  'GRD']

# %%
df=pd.DataFrame(corpus,columns=features[:-3])
df["GRD"]=target

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14561 entries, 0 to 14560
# Data columns (total 66 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Diag01    14561 non-null  object
#  1   Diag02    14561 non-null  object
#  2   Diag03    14561 non-null  object
#  3   Diag04    14561 non-null  object
#  4   Diag05    14561 non-null  object
#  5   Diag06    14561 non-null  object
#  6   Diag07    14561 non-null  object
#  7   Diag08    14561 non-null  object
#  8   Diag09    14561 non-null  object
#  9   Diag10    14561 non-null  object
#  10  Diag11    14561 non-null  object
#  11  Diag12    14561 non-null  object
#  12  Diag13    14561 non-null  object
#  13  Diag14    14561 non-null  object
#  14  Diag15    14561 non-null  object
#  15  Diag16    14561 non-null  object
#  16  Diag17    14561 non-null  object
#  17  Diag18    14561 non-null  object
#  18  Diag19    14561 non-null  object
#  19  Diag20    14561 non-null  object
#  20  Diag21    14561 non-null  object
#  21  Diag22    14561 non-null  object
#  22  Diag23    14561 non-null  object
#  23  Diag24    14561 non-null  object
#  24  Diag25    14561 non-null  object
#  25  Diag26    14561 non-null  object
#  26  Diag27    14561 non-null  object
#  27  Diag28    14561 non-null  object
#  28  Diag29    14561 non-null  object
#  29  Diag30    14561 non-null  object
#  30  Diag31    14561 non-null  object
#  31  Diag32    14561 non-null  object
#  32  Diag33    14561 non-null  object
#  33  Diag34    14561 non-null  object
#  34  Diag35    14561 non-null  object
#  35  Proced01  14561 non-null  object
#  36  Proced02  14561 non-null  object
#  37  Proced03  14561 non-null  object
#  38  Proced04  14561 non-null  object
#  39  Proced05  14561 non-null  object
#  40  Proced06  14561 non-null  object
#  41  Proced07  14561 non-null  object
#  42  Proced08  14561 non-null  object
#  43  Proced09  14561 non-null  object
#  44  Proced10  14561 non-null  object
#  45  Proced11  14561 non-null  object
#  46  Proced12  14561 non-null  object
#  47  Proced13  14561 non-null  object
#  48  Proced14  14561 non-null  object
#  49  Proced15  14561 non-null  object
#  50  Proced16  14561 non-null  object
#  51  Proced17  14561 non-null  object
#  52  Proced18  14561 non-null  object
#  53  Proced19  14561 non-null  object
#  54  Proced20  14561 non-null  object
#  55  Proced21  14561 non-null  object
#  56  Proced22  14561 non-null  object
#  57  Proced23  14561 non-null  object
#  58  Proced24  14561 non-null  object
#  59  Proced25  14561 non-null  object
#  60  Proced26  14561 non-null  object
#  61  Proced27  14561 non-null  object
#  62  Proced28  14561 non-null  object
#  63  Proced29  14561 non-null  object
#  64  Proced30  14561 non-null  object
#  65  GRD       14561 non-null  object
# dtypes: object(66)
# memory usage: 7.3+ MB

# %%
df["GRD"].value_counts()[:20]
# Out:
# GRD
# 146101    813
# 146121    639
# 146131    538
# 158171    389
# 134161    325
# 071141    317
# 044153    287
# 061131    252
# 041023    248
# 146102    244
# 044163    229
# 131111    226
# 131201    222
# 054123    204
# 146122    187
# 146103    163
# 061201    154
# 044183    145
# 146132    140
# 131301    139
# Name: count, dtype: int64

# %%
df["GRD"].value_counts().plot();

# %%
df["GRD"].value_counts()[:20].plot();

# %%
filtro=(df["GRD"]=='146101') | (df["GRD"]=='146102') | (df["GRD"]=='146103')

# %%
df[filtro]
# Out:
#       Diag01 Diag02 Diag03 Diag04 Diag05 Diag06 Diag07 Diag08 Diag09 Diag10  \
# 38     O32.1  O42.1  O82.0  O34.0  O98.1  A53.9  O99.3  F12.2  O99.2  E66.9
# 100    O61.0  O82.1  O24.4  O26.0  Z37.0  Z38.0  Z39.0  Z39.1  Z39.2
# 111    O34.2  O82.1  O24.4  O26.0  Z37.0  Z38.0  Z39.0  Z39.1  Z39.2
# 139    O14.0  O66.4  O82.1  O26.0  Z35.3  Z64.0  Z88.6  Z37.0  Z38.0  Z39.0
# 141    O61.0  O82.1  O99.2  E66.9  Z37.0  Z38.0  Z39.0  Z39.1  Z39.2
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 14534  O61.0  O82.1  Z37.0  Z38.0  Z39.0  Z39.1  Z39.2  Z35.1  Z92.4
# 14535  O61.0  O82.0  Z37.0  Z38.0  Z39.0  Z39.1  Z39.2  Z88.0
# 14538  O82.0  O99.0  O10.0  Z37.0  Z38.0  Z39.0  Z39.1  Z39.2  O62.2
# 14539  O60.1  O82.1  O30.0  O99.2  E66.9  Z37.0  Z38.0  Z39.0  Z39.1  Z39.2
# 14540  O32.1  O82.1  Z37.0  Z38.0  Z39.0  Z39.1  Z39.2
#
#        ... Proced22 Proced23 Proced24 Proced25 Proced26 Proced27 Proced28  \
# 38     ...
# 100    ...
# 111    ...
# 139    ...
# 141    ...
# ...    ...      ...      ...      ...      ...      ...      ...      ...
# 14534  ...
# 14535  ...
# 14538  ...
# 14539  ...
# 14540  ...
#
#       Proced29 Proced30     GRD
# 38                       146102
# 100                      146101
# 111                      146101
# 139                      146101
# 141                      146101
# ...        ...      ...     ...
# 14534                    146102
# 14535                    146101
# 14538                    146102
# 14539                    146101
# 14540                    146101
#
# [1220 rows x 66 columns]

# %%
pd.crosstab(df[filtro]["GRD"],df["Diag01"],margins=True)
# Out:
# Diag01  O03.9  O06.3  O10.0  O10.9  O11  O13  O14.0  O14.1  O14.2  O14.9  ...  \
# GRD                                                                       ...
# 146101      0      1      5      2   14    9      5     22      3      2  ...
# 146102      1      0      0      0    1    4      4     14      2      1  ...
# 146103      0      0      0      0    4    0      0     23      2      1  ...
# All         1      1      5      2   19   13      9     59      7      4  ...
#
# Diag01  O98.4  O98.5  O99.0  O99.2  O99.3  O99.5  O99.6  O99.8  Z35.4   All
# GRD
# 146101      1      0      2      1      0      0      0      1      1   813
# 146102      0      0      1      1      1      1      0      0      0   244
# 146103      0     35      0      0      0      0      1      0      0   163
# All         1     35      3      2      1      1      1      1      1  1220
#
# [4 rows x 105 columns]

# %%
data=df[filtro]

# %%
features_procedimientos=[]
features_diagnosticos=[]
for j in range(1,36):
    field="Diag"+str(j).zfill(2)
    features_diagnosticos.append(field)
for j in range(1,31):
    field="Proced"+str(j).zfill(2)
    features_procedimientos.append(field)

# %%
procedimientos={}
diagnosticos={}
for i, row in data.iterrows():
    for j in range(1,36):
        field="Diag"+str(j).zfill(2)
        if row[field] not in diagnosticos:
            diagnosticos[row[field]]=1
        else:
            diagnosticos[row[field]]+=1
    for j in range(1,31):
        field="Proced"+str(j).zfill(2)
        if row[field] not in procedimientos:
            procedimientos[row[field]]=1
        else:
            procedimientos[row[field]]+=1
token_diagnosticos=list(diagnosticos.keys())
token_procedimientos=list(procedimientos.keys())
vocabulario=len(token_diagnosticos)+len(token_procedimientos)+1
print("Diagnósticos: ",len(token_diagnosticos))
print("Procedimientos: ",len(token_procedimientos))
print("Vocabulario: ",vocabulario)
# Out:
# Diagnósticos:  377
# Procedimientos:  155
# Vocabulario:  533

# %%
token_rows=[]
for i, row in data.iterrows():
    token_row=[]
    for j in range(1,36):
        field="Diag"+str(j).zfill(2)
        token_row.append(1+token_diagnosticos.index(row[field]))
    for j in range(1,31):
        field="Proced"+str(j).zfill(2)
        token_row.append(1+377+token_procedimientos.index(row[field]))
    token_rows.append(token_row)

# %%
import tensorflow as tf
from keras.layers import Attention, Input, Dense, Embedding, Flatten, LSTM
from keras.models import Model,Sequential
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.model_selection import train_test_split
from datetime import datetime
import numpy as np
from keras.utils import pad_sequences

X=pad_sequences(token_rows)

# %%
Y=data["GRD"].apply(lambda x: int(x)).to_numpy()
encoder=LabelEncoder()
encoder.fit(Y)
Y=encoder.transform(Y)
Y=np.asarray(Y)
Y=Y.reshape(-1,1)
encoder=OneHotEncoder()
encoder.fit(Y)
Y=encoder.transform(Y).todense()
print(Y.shape)
# Out:
# (1220, 3)

# %%
X.shape
# Out:
# (1220, 65)

# %%
x_train,x_val,y_train,y_val=train_test_split(X,Y,random_state=0)

# %%
x_train_s=x_train.reshape(-1,65,1)
x_val_s=x_val.reshape(-1,65,1)

# %%
modelo_emb=Sequential()
modelo_emb.add(Embedding(input_dim=vocabulario,output_dim=64))
modelo_emb.add(LSTM(32))
modelo_emb.add(Dense(3,activation="softmax"))
modelo_emb.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["acc"])
modelo_emb.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
tag="emb"+datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = "logs/fit/" + tag
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
spam_emb = modelo_emb.fit(x_train, y_train, validation_data=(x_val,y_val), batch_size=32, epochs=16,verbose=2,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/16
# 29/29 - 2s - 81ms/step - acc: 0.6437 - loss: 0.9053 - val_acc: 0.6689 - val_loss: 0.8678
# Epoch 2/16
# 29/29 - 0s - 16ms/step - acc: 0.6678 - loss: 0.8545 - val_acc: 0.6689 - val_loss: 0.8621
# Epoch 3/16
# 29/29 - 0s - 15ms/step - acc: 0.6689 - loss: 0.8498 - val_acc: 0.6689 - val_loss: 0.8543
# Epoch 4/16
# 29/29 - 0s - 15ms/step - acc: 0.6710 - loss: 0.8345 - val_acc: 0.6787 - val_loss: 0.7996
# Epoch 5/16
# 29/29 - 0s - 15ms/step - acc: 0.6765 - loss: 0.8057 - val_acc: 0.7213 - val_loss: 0.7124
# Epoch 6/16
# 29/29 - 0s - 15ms/step - acc: 0.7180 - loss: 0.7155 - val_acc: 0.7115 - val_loss: 0.6859
# Epoch 7/16
# 29/29 - 0s - 15ms/step - acc: 0.7421 - loss: 0.6583 - val_acc: 0.6721 - val_loss: 0.7662
# Epoch 8/16
# 29/29 - 0s - 15ms/step - acc: 0.7519 - loss: 0.6359 - val_acc: 0.7639 - val_loss: 0.7261
# Epoch 9/16
# 29/29 - 0s - 15ms/step - acc: 0.7672 - loss: 0.6221 - val_acc: 0.8164 - val_loss: 0.5202
# Epoch 10/16
# 29/29 - 0s - 15ms/step - acc: 0.7683 - loss: 0.6059 - val_acc: 0.7967 - val_loss: 0.5851
# Epoch 11/16
# 29/29 - 0s - 15ms/step - acc: 0.7672 - loss: 0.6015 - val_acc: 0.8000 - val_loss: 0.5724
# Epoch 12/16
# 29/29 - 0s - 15ms/step - acc: 0.7016 - loss: 0.6750 - val_acc: 0.4820 - val_loss: 0.9322
# Epoch 13/16
# 29/29 - 0s - 15ms/step - acc: 0.5716 - loss: 0.8499 - val_acc: 0.6689 - val_loss: 0.6779
# Epoch 14/16
# 29/29 - 0s - 15ms/step - acc: 0.6699 - loss: 0.7112 - val_acc: 0.6689 - val_loss: 0.8663
# Epoch 15/16
# 29/29 - 0s - 15ms/step - acc: 0.6842 - loss: 0.7186 - val_acc: 0.8000 - val_loss: 0.6133
# Epoch 16/16
# 29/29 - 0s - 15ms/step - acc: 0.7781 - loss: 0.6043 - val_acc: 0.8000 - val_loss: 0.6012

# %%
modelo_emb.save('modelo{0}.keras'.format(tag))

# %%
modelo_emb=tf.keras.models.load_model('modeloemb20250117-092732.keras')

# %%
y_pred_probs=modelo_emb.predict(x_val)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import label_binarize

# %%
y_pred=np.argmax(y_pred_probs,axis=1)

# %%
fig, axes = plt.subplots(1,4)
fig.set_size_inches(20, 4)

y_val1d=np.squeeze(np.asarray(np.argmax(y_val,axis=1)))

matriz = confusion_matrix(y_val1d, 
                          y_pred)    
ax=axes[0]
sns.heatmap(matriz, annot=True, ax = ax, cmap="Blues",fmt="d");
ax.set_title("Rec="+str(round(recall_score(y_val1d,y_pred,average="macro"),2))+
        " Acc="+str(round(accuracy_score(y_val1d,y_pred),2))+
        " F1="+str(round(f1_score(y_val1d, y_pred,average="macro"),2))+
        " Pre="+str(round(precision_score(y_val1d, y_pred,average="macro"),2)));
axes[0].set_xlabel('Predicted');
axes[0].set_ylabel('Real');

fpr = {}
tpr = {}
roc_auc = {}
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(np.asarray(y_val[:, i]), np.asarray(y_pred_probs[:, i]))
    roc_auc[i] = auc(fpr[i], tpr[i])

for i in range(3):
    axes[i+1].plot(fpr[i], tpr[i])
    axes[i+1].plot([0, 1], [0, 1], 'k--')
    axes[i+1].set_xlabel('FPR')
    axes[i+1].set_ylabel('TPR')
    axes[i+1].set_title('ROC Curve Class {0}, AUC={1}'.format(i,round(roc_auc[i],2)))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
y_pred1d=label_binarize(np.argmax(y_pred_probs,axis=1),classes=[0,1,2])

# %%
for i in range(3):
    print("ACC=",round(accuracy_score(np.squeeze(np.asarray(y_val[:,i])), y_pred1d[:,i]),2),
        "PRE=",round(precision_score(np.squeeze(np.asarray(y_val[:,i])), y_pred1d[:,i]),2),
        "REC=",round(recall_score(np.squeeze(np.asarray(y_val[:,i])), y_pred1d[:,i]),2))
# Out:
# ACC= 0.84 PRE= 0.81 REC= 0.99
# ACC= 0.83 PRE= 0.0 REC= 0.0
# ACC= 0.93 PRE= 0.74 REC= 0.88
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import multilabel_confusion_matrix
multilabel_confusion_matrix(y_val1d,y_pred,labels=[0,1,2])
# Out:
# array([[[ 55,  46],
#         [  3, 201]],
#
#        [[253,   0],
#         [ 52,   0]],
#
#        [[241,  15],
#         [  6,  43]]])

# %%
fig, axes = plt.subplots(1,3)
fig.set_size_inches(15, 4)

for i in range(3):
    lr_precision, lr_recall, thresholds_pr = precision_recall_curve(np.asarray(y_val[:,i]), np.asarray(y_pred_probs[:,i]))
    filtro=np.squeeze(np.asarray(y_val[:,1]==1))
    no_skill = len(y_val[filtro]) / len(y_val)
    p=i
    axes[p].plot(lr_recall, lr_precision, marker='.', label='PR-RC curve (area = %0.2f)' % auc(lr_recall,lr_precision))
    axes[p].plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
    axes[p].set_xlabel('Recall')
    axes[p].set_ylabel('Precision')
    axes[p].set_title('PR-RC Curve %i' % i)
    axes[p].legend();

# %%
test=pd.DataFrame(x_val,columns=features_diagnosticos+features_procedimientos)
test["y"]=np.argmax(y_val,axis=1)
test["yp"]=np.argmax(y_pred_probs,axis=1)

# %%
test[(test["y"]==1) & (test["yp"]==2)]
# Out:
#      Diag01  Diag02  Diag03  Diag04  Diag05  Diag06  Diag07  Diag08  Diag09  \
# 49       47     135      62      22      78       3      35      36      14
# 78      193      22      19      49      52      53      41     251      26
# 90       78     136      69      62     106      35      36      14      15
# 121      65     103      72      19      78       9      10      35      36
# 126      24      19     220      57     132       9      10      12      13
# 133     193      94      69       7     152      21      19      12      13
# 178      31      19      69       9      70      52      71      12      13
# 186     166      22      19      69       9      10      35      36      13
# 192      62     106      19      57      49       9     118     119     120
# 202      31      19      52      71      10      78      35      36      14
# 223      31     193      72      19       9      32      12      13      14
# 269      31     214      72      19      69      49       9     209      10
#
#      Diag10  ...  Proced23  Proced24  Proced25  Proced26  Proced27  Proced28  \
# 49       15  ...       394       394       394       394       394       394
# 78       12  ...       394       394       394       394       394       394
# 90       16  ...       394       394       394       394       394       394
# 121      14  ...       394       394       394       394       394       394
# 126      14  ...       394       394       394       394       394       394
# 133      14  ...       394       394       394       394       394       394
# 178      14  ...       394       394       394       394       394       394
# 186      14  ...       394       394       394       394       394       394
# 192      27  ...       394       394       394       394       394       394
# 202      15  ...       394       394       394       394       394       394
# 223      15  ...       394       394       394       394       394       394
# 269      12  ...       394       394       394       394       394       394
#
#      Proced29  Proced30  y  yp
# 49        394       394  1   2
# 78        394       394  1   2
# 90        394       394  1   2
# 121       394       394  1   2
# 126       394       394  1   2
# 133       394       394  1   2
# 178       394       394  1   2
# 186       394       394  1   2
# 192       394       394  1   2
# 202       394       394  1   2
# 223       394       394  1   2
# 269       394       394  1   2
#
# [12 rows x 67 columns]

# %%
import shap

# %%
explainer = shap.KernelExplainer(modelo_emb.predict, x_val[:20])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
shap_values = explainer.shap_values(x_val[:20])
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1327/1327 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step

# %%
shap.summary_plot(shap_values[:,:,0], plot_type = 'bar',feature_names=features_diagnosticos+features_procedimientos)

# %%
test[(test["y"]==1) & (test["yp"]==2)][["Diag01","Diag02","Diag03","Diag04","Diag05","Diag06"]]
# Out:
#      Diag01  Diag02  Diag03  Diag04  Diag05  Diag06
# 49       47     135      62      22      78       3
# 78      193      22      19      49      52      53
# 90       78     136      69      62     106      35
# 121      65     103      72      19      78       9
# 126      24      19     220      57     132       9
# 133     193      94      69       7     152      21
# 178      31      19      69       9      70      52
# 186     166      22      19      69       9      10
# 192      62     106      19      57      49       9
# 202      31      19      52      71      10      78
# 223      31     193      72      19       9      32
# 269      31     214      72      19      69      49

# %%
filtro1=test[(test["y"]==1)]

# %%
filtro1
# Out:
#      Diag01  Diag02  Diag03  Diag04  Diag05  Diag06  Diag07  Diag08  Diag09  \
# 10       54      37       7      55      56      19      21      12      13
# 13       22       3       9      10      63     298      12      13      14
# 16      162      22      85       3      20      94       9      10      12
# 33        3      57       9     209      12      13      14      15      16
# 38       72      19     164      12      13      14      15      16      17
# 44       72      19      62      65      12      13      14      15      16
# 45        3      20      12      13      14      15      16      43     165
# 49       47     135      62      22      78       3      35      36      14
# 55       23      72      19      69      21      68      12      13      14
# 63       72      19      56      91       9      10      12      13      14
# 66       72     234      33     135      19      49      69      12      13
# 78      193      22      19      49      52      53      41     251      26
# 79       31      19      20       9      10       7      55      12      13
# 90       78     136      69      62     106      35      36      14      15
# 95       22      57       3      12      13      14      15      16      17
# 97       33      23      21      19      12      13      14      15      16
# 104      18      72      91      62      19      12      13      14      15
# 109      22     215     372     373       3      12      13      14      15
# 115      37      19      51     164       9      10      30      29     140
# 121      65     103      72      19      78       9      10      35      36
# 123      72      19       7     233     184     325      12      13      14
# 126      24      19     220      57     132       9      10      12      13
# 133     193      94      69       7     152      21      19      12      13
# 137      28     153      91     303      57      22      21       9     169
# 139      67      57      19      51      96      97       9      10     153
# 149      22      20      62      63     298       3      12      13      14
# 152       1      22       3      20      91       9      10      12      13
# 170      24      19      22      94      12      13      14      15      16
# 178      31      19      69       9      70      52      71      12      13
# 186     166      22      19      69       9      10      35      36      13
# 192      62     106      19      57      49       9     118     119     120
# 195       3      40      20      41      42      12      13      14      15
# 197      46      72      19      12      13      14      15      16      17
# 202      31      19      52      71      10      78      35      36      14
# 203      22       3      57      12      13      14      15      16      17
# 206      62      72      19      12      13      14      15      16      17
# 209      28       3      12      13      14      15      16      43     165
# 211       1      57      19     141      12      13      14      15      16
# 223      31     193      72      19       9      32      12      13      14
# 226      22       3      20       9      32      12      13      14      15
# 236      18     103      19       9      10      12      13      14      15
# 240      22      85       3      20      91      12      13      14      15
# 265      18      56      19      57      49      12      13      14      15
# 269      31     214      72      19      69      49       9     209      10
# 272      72      19      51      23       7     152       9      10      52
# 280      62      65      19      12      13      14      15      16      17
# 285       1      19      65      62      20      12      13      14      15
# 296      31      19      20     111     206      52     354      12      13
# 297     247      65      19       7      99     102      20      12      13
# 298      69     186     187       3      12      13      14      15      16
# 300      18      19     164       9      32       7     152     131      12
# 303     134      19      28      22      57       9      10      12      13
#
#      Diag10  ...  Proced23  Proced24  Proced25  Proced26  Proced27  Proced28  \
# 10       14  ...       391       393       394       394       394       394
# 13       15  ...       394       394       394       394       394       394
# 16       13  ...       394       394       394       394       394       394
# 33      177  ...       394       394       394       394       394       394
# 38       17  ...       394       394       394       394       394       394
# 44      309  ...       394       394       394       394       394       394
# 45       17  ...       394       394       394       394       394       394
# 49       15  ...       394       394       394       394       394       394
# 55       15  ...       394       394       394       394       394       394
# 63       15  ...       394       394       394       394       394       394
# 66       14  ...       394       394       394       394       394       394
# 78       12  ...       394       394       394       394       394       394
# 79       14  ...       394       394       394       394       394       394
# 90       16  ...       394       394       394       394       394       394
# 95       17  ...       394       394       394       394       394       394
# 97      218  ...       394       394       394       394       394       394
# 104      16  ...       394       394       394       394       394       394
# 109      16  ...       394       394       394       394       394       394
# 115      12  ...       394       394       394       394       394       394
# 121      14  ...       394       394       394       394       394       394
# 123      15  ...       394       394       394       394       394       394
# 126      14  ...       394       394       394       394       394       394
# 133      14  ...       394       394       394       394       394       394
# 137      32  ...       394       394       394       394       394       394
# 139      12  ...       394       394       394       394       394       394
# 149      15  ...       394       394       394       394       394       394
# 152      14  ...       394       394       394       394       394       394
# 170      17  ...       394       394       394       394       394       394
# 178      14  ...       394       394       394       394       394       394
# 186      14  ...       394       394       394       394       394       394
# 192      27  ...       394       394       394       394       394       394
# 195      16  ...       394       394       394       394       394       394
# 197      17  ...       394       394       394       394       394       394
# 202      15  ...       394       394       394       394       394       394
# 203      17  ...       394       394       394       394       394       394
# 206      17  ...       394       394       394       394       394       394
# 209      17  ...       394       394       394       394       394       394
# 211      68  ...       394       394       394       394       394       394
# 223      15  ...       394       394       394       394       394       394
# 226      16  ...       394       394       394       394       394       394
# 236      16  ...       394       394       394       394       394       394
# 240      16  ...       394       394       394       394       394       394
# 265      16  ...       394       394       394       394       394       394
# 269      12  ...       394       394       394       394       394       394
# 272     307  ...       394       394       394       394       394       394
# 280      17  ...       394       394       394       394       394       394
# 285      16  ...       394       394       394       394       394       394
# 296      14  ...       394       394       394       394       394       394
# 297      14  ...       394       394       394       394       394       394
# 298      17  ...       394       394       394       394       394       394
# 300      13  ...       394       394       394       394       394       394
# 303      14  ...       394       394       394       394       394       394
#
#      Proced29  Proced30  y  yp
# 10        394       394  1   0
# 13        394       394  1   0
# 16        394       394  1   0
# 33        394       394  1   0
# 38        394       394  1   0
# 44        394       394  1   0
# 45        394       394  1   0
# 49        394       394  1   2
# 55        394       394  1   0
# 63        394       394  1   0
# 66        394       394  1   0
# 78        394       394  1   2
# 79        394       394  1   0
# 90        394       394  1   2
# 95        394       394  1   0
# 97        394       394  1   0
# 104       394       394  1   0
# 109       394       394  1   0
# 115       394       394  1   0
# 121       394       394  1   2
# 123       394       394  1   0
# 126       394       394  1   2
# 133       394       394  1   2
# 137       394       394  1   0
# 139       394       394  1   0
# 149       394       394  1   0
# 152       394       394  1   0
# 170       394       394  1   0
# 178       394       394  1   2
# 186       394       394  1   2
# 192       394       394  1   2
# 195       394       394  1   0
# 197       394       394  1   0
# 202       394       394  1   2
# 203       394       394  1   0
# 206       394       394  1   0
# 209       394       394  1   0
# 211       394       394  1   0
# 223       394       394  1   2
# 226       394       394  1   0
# 236       394       394  1   0
# 240       394       394  1   0
# 265       394       394  1   0
# 269       394       394  1   2
# 272       394       394  1   0
# 280       394       394  1   0
# 285       394       394  1   0
# 296       394       394  1   0
# 297       394       394  1   0
# 298       394       394  1   0
# 300       394       394  1   0
# 303       394       394  1   0
#
# [52 rows x 67 columns]

# %%
y_pred_probs[10]
# Out:
# array([0.80126065, 0.18570636, 0.01303294], dtype=float32)

# %%
shap.plots._waterfall.waterfall_legacy(explainer.expected_value[1], shap_values[10,:,0], feature_names = features_diagnosticos+features_procedimientos)

# %%
pd.crosstab(filtro1["Diag03"],filtro1["yp"])
# Out:
# yp      0  2
# Diag03
# 3       3  0
# 7       2  0
# 9       2  0
# 12      2  0
# 19      9  3
# 20      4  0
# 21      1  0
# 22      1  0
# 28      1  0
# 33      1  0
# 51      2  0
# 52      0  1
# 56      1  0
# 57      1  0
# 62      2  1
# 65      1  0
# 69      0  3
# 72      0  3
# 85      1  0
# 91      2  0
# 164     2  0
# 187     1  0
# 220     0  1
# 372     1  0

# %%
filtro1.loc[10]
# Out:
# Diag01       54
# Diag02       37
# Diag03        7
# Diag04       55
# Diag05       56
#            ...
# Proced28    394
# Proced29    394
# Proced30    394
# y             1
# yp            0
# Name: 10, Length: 67, dtype: int64

# %%
token_diagnosticos[7]
# Out:
# 'F12.2'

# %%
filtro1["Diag03"].value_counts()
# Out:
# Diag03
# 19     12
# 20      4
# 72      3
# 62      3
# 3       3
# 69      3
# 51      2
# 91      2
# 9       2
# 7       2
# 12      2
# 164     2
# 22      1
# 65      1
# 52      1
# 187     1
# 57      1
# 21      1
# 220     1
# 372     1
# 33      1
# 56      1
# 85      1
# 28      1
# Name: count, dtype: int64

# %%
token_diagnosticos[18]
# Out:
# 'O82.1'

# %%
data.query("Diag03=='O82.1'")["GRD"].value_counts()
# Out:
# GRD
# 146101    119
# 146102     46
# 146103     26
# Name: count, dtype: int64

# %%
test["y"].value_counts()
# Out:
# y
# 0    204
# 1     52
# 2     49
# Name: count, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(x_train,np.asarray(np.argmax(y_train,axis=1)))

#Predict the response for test dataset
y_pred_probs = clf.predict_proba(x_val)
y_pred=np.argmax(y_pred_probs,axis=1)

# %%
fig, axes = plt.subplots(1,4)
fig.set_size_inches(20, 4)

y_val1d=np.squeeze(np.asarray(np.argmax(y_val,axis=1)))

matriz = confusion_matrix(y_val1d, 
                          y_pred)    
ax=axes[0]
sns.heatmap(matriz, annot=True, ax = ax, cmap="Blues",fmt="d");
ax.set_title("Rec="+str(round(recall_score(y_val1d,y_pred,average="macro"),2))+
        " Acc="+str(round(accuracy_score(y_val1d,y_pred),2))+
        " F1="+str(round(f1_score(y_val1d, y_pred,average="macro"),2))+
        " Pre="+str(round(precision_score(y_val1d, y_pred,average="macro"),2)));
axes[0].set_xlabel('Predicted');
axes[0].set_ylabel('Real');

fpr = {}
tpr = {}
roc_auc = {}
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(np.asarray(y_val[:, i]), np.asarray(y_pred_probs[:, i]))
    roc_auc[i] = auc(fpr[i], tpr[i])

for i in range(3):
    axes[i+1].plot(fpr[i], tpr[i])
    axes[i+1].plot([0, 1], [0, 1], 'k--')
    axes[i+1].set_xlabel('FPR')
    axes[i+1].set_ylabel('TPR')
    axes[i+1].set_title('ROC Curve Class {0}, AUC={1}'.format(i,round(roc_auc[i],2)))

# %%
plot_tree(clf)
# Out:
# [Text(0.5996382389162561, 0.9722222222222222, 'x[2] <= 56.5\ngini = 0.497\nsamples = 915\nvalue = [609, 192, 114]'),
#  Text(0.33905480295566504, 0.9166666666666666, 'x[1] <= 22.5\ngini = 0.407\nsamples = 722\nvalue = [541, 101, 80]'),
#  Text(0.4693465209359606, 0.9444444444444444, 'True  '),
#  Text(0.14573070607553365, 0.8611111111111112, 'x[9] <= 15.5\ngini = 0.212\nsamples = 471\nvalue = [416, 39, 16]'),
#  Text(0.09113300492610837, 0.8055555555555556, 'x[3] <= 53.5\ngini = 0.521\nsamples = 83\nvalue = [52, 23, 8]'),
#  Text(0.054187192118226604, 0.75, 'x[41] <= 412.0\ngini = 0.401\nsamples = 56\nvalue = [42, 10, 4]'),
#  Text(0.047619047619047616, 0.6944444444444444, 'x[48] <= 410.5\ngini = 0.359\nsamples = 54\nvalue = [42, 10, 2]'),
#  Text(0.029556650246305417, 0.6388888888888888, 'x[46] <= 381.5\ngini = 0.297\nsamples = 51\nvalue = [42, 8, 1]'),
#  Text(0.013136288998357963, 0.5833333333333334, 'x[9] <= 14.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.006568144499178982, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.019704433497536946, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.04597701149425287, 0.5833333333333334, 'x[2] <= 6.0\ngini = 0.245\nsamples = 49\nvalue = [42, 7, 0]'),
#  Text(0.03284072249589491, 0.5277777777777778, 'x[41] <= 384.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4, 0]'),
#  Text(0.026272577996715927, 0.4722222222222222, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.03940886699507389, 0.4722222222222222, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.059113300492610835, 0.5277777777777778, 'x[8] <= 216.5\ngini = 0.139\nsamples = 40\nvalue = [37, 3, 0]'),
#  Text(0.052545155993431854, 0.4722222222222222, 'x[7] <= 11.0\ngini = 0.097\nsamples = 39\nvalue = [37, 2, 0]'),
#  Text(0.03940886699507389, 0.4166666666666667, 'x[42] <= 387.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.03284072249589491, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.04597701149425287, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.06568144499178982, 0.4166666666666667, 'x[38] <= 380.0\ngini = 0.054\nsamples = 36\nvalue = [35, 1, 0]'),
#  Text(0.059113300492610835, 0.3611111111111111, 'x[42] <= 384.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.052545155993431854, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.06568144499178982, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.0722495894909688, 0.3611111111111111, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.06568144499178982, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.06568144499178982, 0.6388888888888888, 'x[45] <= 384.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.059113300492610835, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.0722495894909688, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.060755336617405585, 0.6944444444444444, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.12807881773399016, 0.75, 'x[3] <= 217.5\ngini = 0.609\nsamples = 27\nvalue = [10, 13, 4]'),
#  Text(0.1116584564860427, 0.6944444444444444, 'x[45] <= 391.5\ngini = 0.54\nsamples = 21\nvalue = [5, 13, 3]'),
#  Text(0.09852216748768473, 0.6388888888888888, 'x[3] <= 189.5\ngini = 0.62\nsamples = 10\nvalue = [5, 3, 2]'),
#  Text(0.09195402298850575, 0.5833333333333334, 'x[47] <= 391.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3, 0]'),
#  Text(0.08538587848932677, 0.5277777777777778, 'x[6] <= 11.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0]'),
#  Text(0.07881773399014778, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.09195402298850575, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.09852216748768473, 0.5277777777777778, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.10509031198686371, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.12479474548440066, 0.6388888888888888, 'x[41] <= 381.5\ngini = 0.165\nsamples = 11\nvalue = [0, 10, 1]'),
#  Text(0.11822660098522167, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.13136288998357964, 0.5833333333333334, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.1444991789819376, 0.6944444444444444, 'x[45] <= 400.0\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 1]'),
#  Text(0.13793103448275862, 0.6388888888888888, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.1510673234811166, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.20032840722495895, 0.8055555555555556, 'x[5] <= 24.0\ngini = 0.118\nsamples = 388\nvalue = [364, 16, 8]'),
#  Text(0.1839080459770115, 0.75, 'x[7] <= 55.5\ngini = 0.1\nsamples = 384\nvalue = [364, 13, 7]'),
#  Text(0.17077175697865354, 0.6944444444444444, 'x[47] <= 473.0\ngini = 0.079\nsamples = 367\nvalue = [352, 8, 7]'),
#  Text(0.16420361247947454, 0.6388888888888888, 'x[48] <= 417.5\ngini = 0.074\nsamples = 366\nvalue = [352, 8, 6]'),
#  Text(0.15763546798029557, 0.5833333333333334, 'x[52] <= 408.5\ngini = 0.069\nsamples = 365\nvalue = [352, 8, 5]'),
#  Text(0.1510673234811166, 0.5277777777777778, 'x[11] <= 212.0\ngini = 0.064\nsamples = 364\nvalue = [352, 8, 4]'),
#  Text(0.1444991789819376, 0.4722222222222222, 'x[6] <= 116.5\ngini = 0.059\nsamples = 363\nvalue = [352, 7, 4]'),
#  Text(0.13793103448275862, 0.4166666666666667, 'x[47] <= 388.0\ngini = 0.054\nsamples = 362\nvalue = [352, 6, 4]'),
#  Text(0.10509031198686371, 0.3611111111111111, 'x[3] <= 59.0\ngini = 0.3\nsamples = 29\nvalue = [24, 3, 2]'),
#  Text(0.09852216748768473, 0.3055555555555556, 'x[3] <= 7.0\ngini = 0.253\nsamples = 28\nvalue = [24, 3, 1]'),
#  Text(0.09195402298850575, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.10509031198686371, 0.25, 'x[8] <= 55.5\ngini = 0.203\nsamples = 27\nvalue = [24, 2, 1]'),
#  Text(0.09852216748768473, 0.19444444444444445, 'x[4] <= 43.0\ngini = 0.145\nsamples = 26\nvalue = [24, 1, 1]'),
#  Text(0.09195402298850575, 0.1388888888888889, 'x[43] <= 423.5\ngini = 0.077\nsamples = 25\nvalue = [24, 0, 1]'),
#  Text(0.08538587848932677, 0.08333333333333333, 'gini = 0.0\nsamples = 23\nvalue = [23, 0, 0]'),
#  Text(0.09852216748768473, 0.08333333333333333, 'x[38] <= 382.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.09195402298850575, 0.027777777777777776, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.10509031198686371, 0.027777777777777776, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.10509031198686371, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.1116584564860427, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.1116584564860427, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.17077175697865354, 0.3611111111111111, 'x[44] <= 418.0\ngini = 0.03\nsamples = 333\nvalue = [328, 3, 2]'),
#  Text(0.1510673234811166, 0.3055555555555556, 'x[4] <= 6.0\ngini = 0.024\nsamples = 330\nvalue = [326, 3, 1]'),
#  Text(0.13136288998357964, 0.25, 'x[39] <= 384.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.12479474548440066, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.13793103448275862, 0.19444444444444445, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.17077175697865354, 0.25, 'x[36] <= 380.5\ngini = 0.018\nsamples = 327\nvalue = [324, 2, 1]'),
#  Text(0.1510673234811166, 0.19444444444444445, 'x[2] <= 6.0\ngini = 0.124\nsamples = 30\nvalue = [28, 2, 0]'),
#  Text(0.1444991789819376, 0.1388888888888889, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.15763546798029557, 0.1388888888888889, 'x[4] <= 41.0\ngini = 0.067\nsamples = 29\nvalue = [28, 1, 0]'),
#  Text(0.1510673234811166, 0.08333333333333333, 'gini = 0.0\nsamples = 28\nvalue = [28, 0, 0]'),
#  Text(0.16420361247947454, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.19047619047619047, 0.19444444444444445, 'x[46] <= 384.5\ngini = 0.007\nsamples = 297\nvalue = [296, 0, 1]'),
#  Text(0.1839080459770115, 0.1388888888888889, 'x[4] <= 11.0\ngini = 0.095\nsamples = 20\nvalue = [19, 0, 1]'),
#  Text(0.17733990147783252, 0.08333333333333333, 'x[2] <= 27.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.17077175697865354, 0.027777777777777776, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.1839080459770115, 0.027777777777777776, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.19047619047619047, 0.08333333333333333, 'gini = 0.0\nsamples = 18\nvalue = [18, 0, 0]'),
#  Text(0.19704433497536947, 0.1388888888888889, 'gini = 0.0\nsamples = 277\nvalue = [277, 0, 0]'),
#  Text(0.19047619047619047, 0.3055555555555556, 'x[45] <= 384.0\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.1839080459770115, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.19704433497536947, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.1510673234811166, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.15763546798029557, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.16420361247947454, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.17077175697865354, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.17733990147783252, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.19704433497536947, 0.6944444444444444, 'x[44] <= 392.5\ngini = 0.415\nsamples = 17\nvalue = [12, 5, 0]'),
#  Text(0.19047619047619047, 0.6388888888888888, 'x[43] <= 387.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5, 0]'),
#  Text(0.1839080459770115, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.19704433497536947, 0.5833333333333334, 'x[8] <= 91.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3, 0]'),
#  Text(0.1839080459770115, 0.5277777777777778, 'x[40] <= 382.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0]'),
#  Text(0.17733990147783252, 0.4722222222222222, 'x[7] <= 116.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.17077175697865354, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.1839080459770115, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.19047619047619047, 0.4722222222222222, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.21018062397372742, 0.5277777777777778, 'x[0] <= 9.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.20361247947454844, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.21674876847290642, 0.4722222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.20361247947454844, 0.6388888888888888, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0]'),
#  Text(0.21674876847290642, 0.75, 'x[41] <= 386.0\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.21018062397372742, 0.6944444444444444, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.2233169129720854, 0.6944444444444444, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.5323788998357963, 0.8611111111111112, 'x[6] <= 19.5\ngini = 0.626\nsamples = 251\nvalue = [125, 62, 64]'),
#  Text(0.4375, 0.8055555555555556, 'x[2] <= 29.5\ngini = 0.595\nsamples = 210\nvalue = [115.0, 56.0, 39.0]'),
#  Text(0.35283251231527096, 0.75, 'x[3] <= 20.5\ngini = 0.538\nsamples = 172\nvalue = [106, 44, 22]'),
#  Text(0.2623152709359606, 0.6944444444444444, 'x[43] <= 382.5\ngini = 0.427\nsamples = 102\nvalue = [74.0, 21.0, 7.0]'),
#  Text(0.23645320197044334, 0.6388888888888888, 'x[0] <= 47.0\ngini = 0.554\nsamples = 17\nvalue = [8, 8, 1]'),
#  Text(0.22988505747126436, 0.5833333333333334, 'x[38] <= 394.5\ngini = 0.198\nsamples = 9\nvalue = [0, 8, 1]'),
#  Text(0.2233169129720854, 0.5277777777777778, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0]'),
#  Text(0.23645320197044334, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.24302134646962234, 0.5833333333333334, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0]'),
#  Text(0.2881773399014778, 0.6388888888888888, 'x[5] <= 211.0\ngini = 0.369\nsamples = 85\nvalue = [66.0, 13.0, 6.0]'),
#  Text(0.28160919540229884, 0.5833333333333334, 'x[3] <= 5.0\ngini = 0.345\nsamples = 83\nvalue = [66, 11, 6]'),
#  Text(0.24958949096880131, 0.5277777777777778, 'x[0] <= 25.0\ngini = 0.628\nsamples = 11\nvalue = [5, 4, 2]'),
#  Text(0.24302134646962234, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.2561576354679803, 0.4722222222222222, 'x[0] <= 55.5\ngini = 0.531\nsamples = 8\nvalue = [5, 1, 2]'),
#  Text(0.24958949096880131, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.2627257799671593, 0.4166666666666667, 'x[4] <= 16.0\ngini = 0.625\nsamples = 4\nvalue = [1, 1, 2]'),
#  Text(0.2561576354679803, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.26929392446633826, 0.3611111111111111, 'x[45] <= 387.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.2627257799671593, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.27586206896551724, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.3136288998357964, 0.5277777777777778, 'x[1] <= 35.5\ngini = 0.27\nsamples = 72\nvalue = [61, 7, 4]'),
#  Text(0.2955665024630542, 0.4722222222222222, 'x[39] <= 386.5\ngini = 0.494\nsamples = 9\nvalue = [5, 0, 4]'),
#  Text(0.2889983579638752, 0.4166666666666667, 'x[43] <= 397.0\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 4]'),
#  Text(0.2824302134646962, 0.3611111111111111, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.2955665024630542, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.3021346469622332, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.33169129720853857, 0.4722222222222222, 'x[7] <= 91.0\ngini = 0.198\nsamples = 63\nvalue = [56, 7, 0]'),
#  Text(0.3251231527093596, 0.4166666666666667, 'x[5] <= 12.5\ngini = 0.175\nsamples = 62\nvalue = [56, 6, 0]'),
#  Text(0.30870279146141216, 0.3611111111111111, 'x[38] <= 389.5\ngini = 0.363\nsamples = 21\nvalue = [16, 5, 0]'),
#  Text(0.2955665024630542, 0.3055555555555556, 'x[47] <= 390.5\ngini = 0.208\nsamples = 17\nvalue = [15, 2, 0]'),
#  Text(0.2889983579638752, 0.25, 'x[40] <= 383.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0]'),
#  Text(0.2824302134646962, 0.19444444444444445, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.2955665024630542, 0.19444444444444445, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.3021346469622332, 0.25, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0]'),
#  Text(0.3218390804597701, 0.3055555555555556, 'x[50] <= 393.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0]'),
#  Text(0.31527093596059114, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.3284072249589491, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.3415435139573071, 0.3611111111111111, 'x[42] <= 394.5\ngini = 0.048\nsamples = 41\nvalue = [40, 1, 0]'),
#  Text(0.33497536945812806, 0.3055555555555556, 'gini = 0.0\nsamples = 33\nvalue = [33, 0, 0]'),
#  Text(0.34811165845648606, 0.3055555555555556, 'x[39] <= 388.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1, 0]'),
#  Text(0.3415435139573071, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0]'),
#  Text(0.35467980295566504, 0.25, 'x[1] <= 178.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.34811165845648606, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.361247947454844, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.33825944170771755, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.2947454844006568, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.4433497536945813, 0.6944444444444444, 'x[44] <= 390.5\ngini = 0.637\nsamples = 70\nvalue = [32, 23, 15]'),
#  Text(0.4039408866995074, 0.6388888888888888, 'x[38] <= 390.0\ngini = 0.584\nsamples = 39\nvalue = [22, 7, 10]'),
#  Text(0.37766830870279144, 0.5833333333333334, 'x[10] <= 155.5\ngini = 0.449\nsamples = 28\nvalue = [20, 4, 4]'),
#  Text(0.37110016420361247, 0.5277777777777778, 'x[36] <= 380.5\ngini = 0.379\nsamples = 26\nvalue = [20, 4, 2]'),
#  Text(0.3579638752052545, 0.4722222222222222, 'x[3] <= 52.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3, 0]'),
#  Text(0.35139573070607555, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.3645320197044335, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.3842364532019704, 0.4722222222222222, 'x[41] <= 388.5\ngini = 0.254\nsamples = 21\nvalue = [18, 1, 2]'),
#  Text(0.37766830870279144, 0.4166666666666667, 'gini = 0.0\nsamples = 16\nvalue = [16, 0, 0]'),
#  Text(0.39080459770114945, 0.4166666666666667, 'x[3] <= 40.0\ngini = 0.64\nsamples = 5\nvalue = [2, 1, 2]'),
#  Text(0.3842364532019704, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.3973727422003284, 0.3611111111111111, 'x[3] <= 92.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.39080459770114945, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.4039408866995074, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3842364532019704, 0.5277777777777778, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4302134646962233, 0.5833333333333334, 'x[2] <= 19.5\ngini = 0.595\nsamples = 11\nvalue = [2, 3, 6]'),
#  Text(0.4236453201970443, 0.5277777777777778, 'x[3] <= 166.0\ngini = 0.494\nsamples = 9\nvalue = [2, 1, 6]'),
#  Text(0.41050903119868637, 0.4722222222222222, 'x[9] <= 152.5\ngini = 0.245\nsamples = 7\nvalue = [1, 0, 6]'),
#  Text(0.4039408866995074, 0.4166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(0.41707717569786534, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.4367816091954023, 0.4722222222222222, 'x[5] <= 11.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.4302134646962233, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.4433497536945813, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.4367816091954023, 0.5277777777777778, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.4827586206896552, 0.6388888888888888, 'x[1] <= 164.0\ngini = 0.604\nsamples = 31\nvalue = [10, 16, 5]'),
#  Text(0.47619047619047616, 0.5833333333333334, 'x[42] <= 391.5\ngini = 0.579\nsamples = 28\nvalue = [7, 16, 5]'),
#  Text(0.45648604269293924, 0.5277777777777778, 'x[0] <= 41.5\ngini = 0.449\nsamples = 21\nvalue = [3, 15, 3]'),
#  Text(0.44991789819376027, 0.4722222222222222, 'gini = 0.0\nsamples = 9\nvalue = [0, 9, 0]'),
#  Text(0.4630541871921182, 0.4722222222222222, 'x[6] <= 13.5\ngini = 0.625\nsamples = 12\nvalue = [3, 6, 3]'),
#  Text(0.45648604269293924, 0.4166666666666667, 'x[5] <= 11.0\ngini = 0.667\nsamples = 9\nvalue = [3, 3, 3]'),
#  Text(0.44991789819376027, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4630541871921182, 0.3611111111111111, 'x[39] <= 386.0\ngini = 0.612\nsamples = 7\nvalue = [3, 3, 1]'),
#  Text(0.45648604269293924, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.4696223316912972, 0.3055555555555556, 'x[37] <= 400.5\ngini = 0.56\nsamples = 5\nvalue = [3, 1, 1]'),
#  Text(0.4630541871921182, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.47619047619047616, 0.25, 'x[0] <= 138.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.4696223316912972, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4827586206896552, 0.19444444444444445, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.4696223316912972, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.49589490968801314, 0.5277777777777778, 'x[41] <= 392.0\ngini = 0.571\nsamples = 7\nvalue = [4, 1, 2]'),
#  Text(0.48932676518883417, 0.4722222222222222, 'x[9] <= 14.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1, 0]'),
#  Text(0.4827586206896552, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.49589490968801314, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.5024630541871922, 0.4722222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.48932676518883417, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.5221674876847291, 0.75, 'x[2] <= 38.0\ngini = 0.644\nsamples = 38\nvalue = [9, 12, 17]'),
#  Text(0.5024630541871922, 0.6944444444444444, 'x[9] <= 16.5\ngini = 0.153\nsamples = 12\nvalue = [0, 1, 11]'),
#  Text(0.49589490968801314, 0.6388888888888888, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11]'),
#  Text(0.5090311986863711, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.541871921182266, 0.6944444444444444, 'x[1] <= 39.5\ngini = 0.648\nsamples = 26\nvalue = [9, 11, 6]'),
#  Text(0.5221674876847291, 0.6388888888888888, 'x[38] <= 382.5\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 3]'),
#  Text(0.5155993431855501, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5287356321839081, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.5615763546798029, 0.6388888888888888, 'x[39] <= 387.5\ngini = 0.549\nsamples = 18\nvalue = [4, 11, 3]'),
#  Text(0.541871921182266, 0.5833333333333334, 'x[38] <= 395.0\ngini = 0.292\nsamples = 12\nvalue = [1, 10, 1]'),
#  Text(0.535303776683087, 0.5277777777777778, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.548440065681445, 0.5277777777777778, 'x[46] <= 394.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.541871921182266, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.555008210180624, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5812807881773399, 0.5833333333333334, 'x[1] <= 66.5\ngini = 0.611\nsamples = 6\nvalue = [3, 1, 2]'),
#  Text(0.5747126436781609, 0.5277777777777778, 'x[46] <= 393.5\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5681444991789819, 0.4722222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5812807881773399, 0.4722222222222222, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5878489326765188, 0.5277777777777778, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.6272577996715928, 0.8055555555555556, 'x[39] <= 384.5\ngini = 0.547\nsamples = 41\nvalue = [10, 6, 25]'),
#  Text(0.6141215106732348, 0.75, 'x[39] <= 380.0\ngini = 0.277\nsamples = 19\nvalue = [2, 1, 16]'),
#  Text(0.6075533661740559, 0.6944444444444444, 'x[1] <= 113.0\ngini = 0.64\nsamples = 5\nvalue = [2, 1, 2]'),
#  Text(0.6009852216748769, 0.6388888888888888, 'x[37] <= 383.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5944170771756979, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6075533661740559, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.6141215106732348, 0.6388888888888888, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.6206896551724138, 0.6944444444444444, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14]'),
#  Text(0.6403940886699507, 0.75, 'x[10] <= 13.5\ngini = 0.649\nsamples = 22\nvalue = [8, 5, 9]'),
#  Text(0.6338259441707718, 0.6944444444444444, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.6469622331691297, 0.6944444444444444, 'x[4] <= 63.0\ngini = 0.637\nsamples = 17\nvalue = [8, 5, 4]'),
#  Text(0.6338259441707718, 0.6388888888888888, 'x[38] <= 382.5\ngini = 0.48\nsamples = 10\nvalue = [6, 0, 4]'),
#  Text(0.6272577996715928, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.6403940886699507, 0.5833333333333334, 'x[42] <= 386.5\ngini = 0.444\nsamples = 6\nvalue = [2, 0, 4]'),
#  Text(0.6338259441707718, 0.5277777777777778, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.6469622331691297, 0.5277777777777778, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.6600985221674877, 0.6388888888888888, 'x[7] <= 85.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5, 0]'),
#  Text(0.6535303776683087, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8602216748768473, 0.9166666666666666, 'x[2] <= 57.5\ngini = 0.623\nsamples = 193\nvalue = [68, 91, 34]'),
#  Text(0.7299299568965517, 0.9444444444444444, '  False'),
#  Text(0.8536535303776683, 0.8611111111111112, 'gini = 0.0\nsamples = 28\nvalue = [0, 28, 0]'),
#  Text(0.8667898193760263, 0.8611111111111112, 'x[7] <= 16.5\ngini = 0.642\nsamples = 165\nvalue = [68, 63, 34]'),
#  Text(0.7943349753694581, 0.8055555555555556, 'x[3] <= 28.0\ngini = 0.586\nsamples = 125\nvalue = [65, 45, 15]'),
#  Text(0.7134646962233169, 0.75, 'x[2] <= 85.5\ngini = 0.474\nsamples = 79\nvalue = [50, 28, 1]'),
#  Text(0.6929392446633826, 0.6944444444444444, 'x[5] <= 163.0\ngini = 0.18\nsamples = 30\nvalue = [27, 3, 0]'),
#  Text(0.6863711001642037, 0.6388888888888888, 'x[8] <= 60.0\ngini = 0.128\nsamples = 29\nvalue = [27, 2, 0]'),
#  Text(0.6798029556650246, 0.5833333333333334, 'x[0] <= 2.0\ngini = 0.069\nsamples = 28\nvalue = [27, 1, 0]'),
#  Text(0.6732348111658456, 0.5277777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6863711001642037, 0.5277777777777778, 'gini = 0.0\nsamples = 27\nvalue = [27, 0, 0]'),
#  Text(0.6929392446633826, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6995073891625616, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7339901477832512, 0.6944444444444444, 'x[2] <= 98.0\ngini = 0.519\nsamples = 49\nvalue = [23.0, 25.0, 1.0]'),
#  Text(0.7126436781609196, 0.6388888888888888, 'x[10] <= 68.0\ngini = 0.133\nsamples = 14\nvalue = [1, 13, 0]'),
#  Text(0.7060755336617406, 0.5833333333333334, 'gini = 0.0\nsamples = 13\nvalue = [0, 13, 0]'),
#  Text(0.7192118226600985, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.7553366174055829, 0.6388888888888888, 'x[41] <= 384.5\ngini = 0.487\nsamples = 35\nvalue = [22, 12, 1]'),
#  Text(0.7323481116584565, 0.5833333333333334, 'x[46] <= 391.5\ngini = 0.5\nsamples = 14\nvalue = [4, 9, 1]'),
#  Text(0.7192118226600985, 0.5277777777777778, 'x[9] <= 78.5\ngini = 0.56\nsamples = 5\nvalue = [3, 1, 1]'),
#  Text(0.7126436781609196, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.7257799671592775, 0.4722222222222222, 'x[1] <= 70.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.7192118226600985, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7323481116584565, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7454844006568144, 0.5277777777777778, 'x[8] <= 16.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8, 0]'),
#  Text(0.7389162561576355, 0.4722222222222222, 'gini = 0.0\nsamples = 7\nvalue = [0, 7, 0]'),
#  Text(0.7520525451559934, 0.4722222222222222, 'x[8] <= 91.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.7454844006568144, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.7586206896551724, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7783251231527094, 0.5833333333333334, 'x[43] <= 393.5\ngini = 0.245\nsamples = 21\nvalue = [18, 3, 0]'),
#  Text(0.7717569786535303, 0.5277777777777778, 'gini = 0.0\nsamples = 14\nvalue = [14, 0, 0]'),
#  Text(0.7848932676518884, 0.5277777777777778, 'x[0] <= 23.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3, 0]'),
#  Text(0.7783251231527094, 0.4722222222222222, 'x[40] <= 391.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0]'),
#  Text(0.7717569786535303, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.7848932676518884, 0.4166666666666667, 'x[5] <= 13.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.7783251231527094, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7914614121510674, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.7914614121510674, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.8752052545155994, 0.75, 'x[3] <= 34.5\ngini = 0.664\nsamples = 46\nvalue = [15, 17, 14]'),
#  Text(0.8686371100164204, 0.6944444444444444, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.8817733990147784, 0.6944444444444444, 'x[1] <= 77.5\ngini = 0.652\nsamples = 42\nvalue = [15, 17, 10]'),
#  Text(0.8686371100164204, 0.6388888888888888, 'x[2] <= 227.5\ngini = 0.651\nsamples = 35\nvalue = [15, 11, 9]'),
#  Text(0.8620689655172413, 0.5833333333333334, 'x[36] <= 389.0\ngini = 0.664\nsamples = 30\nvalue = [10, 11, 9]'),
#  Text(0.8407224958949097, 0.5277777777777778, 'x[6] <= 22.5\ngini = 0.586\nsamples = 18\nvalue = [3, 10, 5]'),
#  Text(0.8341543513957307, 0.4722222222222222, 'x[1] <= 56.0\ngini = 0.498\nsamples = 15\nvalue = [3, 10, 2]'),
#  Text(0.8177339901477833, 0.4166666666666667, 'x[3] <= 192.0\ngini = 0.375\nsamples = 12\nvalue = [3, 9, 0]'),
#  Text(0.8045977011494253, 0.3611111111111111, 'x[9] <= 66.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8, 0]'),
#  Text(0.7980295566502463, 0.3055555555555556, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0]'),
#  Text(0.8111658456486043, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8308702791461412, 0.3611111111111111, 'x[5] <= 13.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.8243021346469622, 0.3055555555555556, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8374384236453202, 0.3055555555555556, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8505747126436781, 0.4166666666666667, 'x[47] <= 388.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.8440065681444991, 0.3611111111111111, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8571428571428571, 0.3611111111111111, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8472906403940886, 0.4722222222222222, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.8834154351395731, 0.5277777777777778, 'x[3] <= 119.5\ngini = 0.542\nsamples = 12\nvalue = [7, 1, 4]'),
#  Text(0.8702791461412152, 0.4722222222222222, 'x[2] <= 204.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1, 0]'),
#  Text(0.8637110016420362, 0.4166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0]'),
#  Text(0.8768472906403941, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.896551724137931, 0.4722222222222222, 'x[0] <= 67.5\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 4]'),
#  Text(0.8899835796387521, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.90311986863711, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8752052545155994, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.8949096880131363, 0.6388888888888888, 'x[11] <= 14.0\ngini = 0.245\nsamples = 7\nvalue = [0, 6, 1]'),
#  Text(0.8883415435139573, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9014778325123153, 0.5833333333333334, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.9392446633825944, 0.8055555555555556, 'x[38] <= 382.5\ngini = 0.566\nsamples = 40\nvalue = [3, 18, 19]'),
#  Text(0.9211822660098522, 0.75, 'x[46] <= 384.5\ngini = 0.32\nsamples = 15\nvalue = [0, 12, 3]'),
#  Text(0.9146141215106732, 0.6944444444444444, 'x[52] <= 392.5\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(0.9080459770114943, 0.6388888888888888, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9211822660098522, 0.6388888888888888, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.9277504105090312, 0.6944444444444444, 'gini = 0.0\nsamples = 11\nvalue = [0, 11, 0]'),
#  Text(0.9573070607553367, 0.75, 'x[44] <= 389.5\ngini = 0.518\nsamples = 25\nvalue = [3, 6, 16]'),
#  Text(0.9408866995073891, 0.6944444444444444, 'x[47] <= 419.5\ngini = 0.231\nsamples = 15\nvalue = [0, 2, 13]'),
#  Text(0.9343185550082101, 0.6388888888888888, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13]'),
#  Text(0.9474548440065681, 0.6388888888888888, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.9737274220032841, 0.6944444444444444, 'x[6] <= 43.5\ngini = 0.66\nsamples = 10\nvalue = [3, 4, 3]'),
#  Text(0.9605911330049262, 0.6388888888888888, 'x[6] <= 19.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4, 0]'),
#  Text(0.9540229885057471, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9671592775041051, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.986863711001642, 0.6388888888888888, 'x[4] <= 15.0\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 3]'),
#  Text(0.9802955665024631, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.993431855500821, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]')]
